# %%
#Importing Libraries

from collections import Counter
import json
from pathlib import Path
import random
import pandas as pd
import spacy

# %%
# Confirming and setting project path

BASE_DIR = Path.cwd().parent
RAW_DIR = BASE_DIR / "Data" / "Raw" #Contains datasets csv
PROJECT_ROOT = BASE_DIR / "Data" / "Processed"
SPLIT_DATA = BASE_DIR / "Data" / "Splits"
SRC = BASE_DIR / "Src" / "Training"
MODEL_PATH = BASE_DIR / "Models" / "spacy_baseline"
print(BASE_DIR)
print(RAW_DIR)
print(PROJECT_ROOT)
print(SPLIT_DATA)
print(SRC)
print(MODEL_PATH)
# Out:
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Data\Raw
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Data\Processed
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Data\Splits
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Src\Training
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Models\spacy_baseline

# %%
# # -optimize efficiency/generate config once.
# RUN ONLY ONCE WHEN CREATING A NEW CONFIG

# import sys

# !"{sys.executable}" -m spacy init config "{SRC / 'config.cfg'}" --lang en --pipeline ner --optimize efficiency

# %%
#Verification:

import os
print(os.getcwd())
print(os.path.exists("../Src/Training/config.cfg"))
# Out:
# D:\PycharmProjects\DS Projects\Healthcare NLP Auto-Labeling System_Final\Notebooks
# True

# %%
from pathlib import Path

print(Path("../Data/Processed/train.spacy").exists())
print(Path("../Data/Processed/valid.spacy").exists())
# Out:
# True
# True

# %%
from pathlib import Path

print(Path("../Data/Processed/train.spacy"))
print(Path("../Data/Processed/valid.spacy"))
# Out:
# ..\Data\Processed\train.spacy
# ..\Data\Processed\valid.spacy

# %%
import sys

!"{sys.executable}" -m spacy train "D:/PycharmProjects/DS Projects/Healthcare NLP Auto-Labeling System_Final/Src/Training/config.cfg" --output "D:/PycharmProjects/DS Projects/Healthcare NLP Auto-Labeling System_Final/Models/spacy_baseline"
# Out:
# ℹ Saving to output directory: D:\PycharmProjects\DS Projects\Healthcare
# NLP Auto-Labeling System_Final\Models\spacy_baseline
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     61.14    0.00    0.00    0.00    0.00
#   0     200        105.19   2822.75   98.25   98.22   98.28    0.98
#   0     400         15.16     28.77   99.97   99.94  100.00    1.00
#   1     600          5.63      3.95   99.97   99.94  100.00    1.00
#   1     800          4.39      2.35   99.97  100.00   99.94    1.00
#   2    1000          4.51      2.03   99.97   99.94  100.00    1.00
# ...
